# %%
import os
import pandas as pd
import seaborn as sns
import regex as re
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %% [markdown]
# A continuación, se precede con la limpieza del dataset del CSV "data_movies_info_1970-2022.csv" que se obtuvo en el notebook "1.movies_API_raw_informacion.ipybn".

# %%
path_o = str(os.getcwd()).split("\\")
path_o = "\\".join(path_o[:-1])

# %%
os.chdir(path_o+"\\data\\raw")
df_raw = pd.read_csv("data_movies_info_1970-2022.csv", index_col=0)
df_raw.head()
# Out:
#        id  adult  budget                                             genres  \
# 0  960074  False       0  [{'id': 37, 'name': 'Western'}, {'id': 12, 'na...
# 1  960071  False       0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 2  959620  False       0                [{'id': 99, 'name': 'Documentary'}]
# 3  958630  False       0                [{'id': 99, 'name': 'Documentary'}]
# 4  958158  False       0  [{'id': 10751, 'name': 'Family'}, {'id': 10770...
#
#   original_language                original_title  popularity  \
# 0                tr                  Ölüm Fermanı        0.60
# 1                en                   Güzel Şoför        0.60
# 2                en         My Valley is Changing        1.09
# 3                pt  Luiz Gonzaga, o Rei do Baião        0.60
# 4                pl              Słodka tajemnica        0.60
#
#                                 production_companies  \
# 0  [{'id': 12793, 'logo_path': None, 'name': 'Top...
# ...

# %%
df_raw.describe()
# Out:
#                   id        budget     popularity       revenue  \
# count  347700.000000  3.477000e+05  347700.000000  3.477000e+05
# mean   451245.627176  5.252775e+05       1.954777  1.326524e+06
# std    273153.512133  6.099140e+06      21.376197  2.198398e+07
# min         2.000000  0.000000e+00       0.000000 -1.200000e+01
# 25%    241220.250000  0.000000e+00       0.600000  0.000000e+00
# 50%    437851.500000  0.000000e+00       0.600000  0.000000e+00
# 75%    678721.250000  0.000000e+00       1.211000  0.000000e+00
# max    960198.000000  3.800000e+08    6587.056000  2.797801e+09
#
#              runtime   vote_average     vote_count
# count  328149.000000  347700.000000  347700.000000
# mean       56.912616       2.583179      33.322565
# std        71.507345       3.128805     413.289775
# min         0.000000       0.000000       0.000000
# 25%         7.000000       0.000000       0.000000
# 50%        60.000000       0.000000       0.000000
# ...

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 347700 entries, 0 to 347699
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     347700 non-null  int64
#  1   adult                  347700 non-null  bool
#  2   budget                 347700 non-null  int64
#  3   genres                 347700 non-null  object
#  4   original_language      347700 non-null  object
#  5   original_title         347699 non-null  object
#  6   popularity             347700 non-null  float64
#  7   production_companies   347700 non-null  object
#  8   production_countries   347700 non-null  object
#  9   release_date           347699 non-null  object
#  10  revenue                347700 non-null  int64
#  11  runtime                328149 non-null  float64
#  12  spoken_languages       347700 non-null  object
#  13  status                 347700 non-null  object
# ...

# %%
df_raw.columns
# Out:
# Index(['id', 'adult', 'budget', 'genres', 'original_language',
#        'original_title', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'vote_average', 'vote_count',
#        'video', 'title', 'belongs_to_collection', 'overview', 'homepage',
#        'imdb_id', 'poster_path', 'crew', 'cast', 'keywords'],
#       dtype='object')

# %% [markdown]
# La siguiente función elimina todas aquellas incosistencias del dataset, como por ejemplo, eliminar los registros en que la duración de la película es 0, también se considero para el análisis los largometrajes, que según el blog 20minutos, La Academy of Motion Picture Arts and Sciences (EEUU) y la British Film Institute (Reino Unido) recogen que debe tener una duración mínima de 40 minutos. [Referencia](https://blogs.20minutos.es/yaestaellistoquetodolosabe/que-duracion-debe-tener-una-pelicula-para-ser-considerada-como-largometraje/). Por lo tanto, todos los registros con menos de 40 minutos de duración se eliminarán.

# %% [markdown]
# Otras modificaciones que se realizán en la función son:
# - Eliminar películas que se encuentran en producción
# - La columna target (revenue) con valores igual a cero, que se debe a falta de información en ese campo.

# %%
os.chdir(path_o+"\\utils")
from funciones_clean_information import clean_data
df_raw_c = clean_data(df_raw)
df_raw_c.head()
# Out:
#          id  adult    budget  \
# 1013  11589  False   4000000
# 1231  11202  False  12000000
# 1240  11165  False  25485000
# 1399  42345  False  11000000
# 1408   2998  False   7000000
#
#                                                  genres original_language  \
# 1013  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...                en
# 1231  [{'id': 10752, 'name': 'War'}, {'id': 18, 'nam...                en
# 1240  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...                en
# 1399  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...                en
# 1408  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...                en
#
#           original_title  popularity  \
# 1013      Kelly's Heroes      13.786
# 1231              Patton      13.992
# 1240   Tora! Tora! Tora!      12.843
# 1399  The Molly Maguires       7.413
# 1408     Zabriskie Point       7.859
#
#                                    production_companies  \
# ...

# %%
df_raw_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5343 entries, 1013 to 345556
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     5343 non-null   int64
#  1   adult                  5343 non-null   bool
#  2   budget                 5343 non-null   int64
#  3   genres                 5343 non-null   object
#  4   original_language      5343 non-null   object
#  5   original_title         5343 non-null   object
#  6   popularity             5343 non-null   float64
#  7   production_companies   5343 non-null   object
#  8   production_countries   5343 non-null   object
#  9   release_date           5343 non-null   object
#  10  revenue                5343 non-null   int64
#  11  runtime                5343 non-null   float64
#  12  spoken_languages       5343 non-null   object
#  13  status                 5343 non-null   object
# ...

# %%
os.chdir(path_o+"\\data\\raw")
df_raw_c.to_csv("data_clean_movies_info.csv")
